# %% [markdown]
# <br>
#
# <img src='ml4.png'/>
#
# <h2 style="color: blue"> Data Science or Analytics LandScape </h2>
#
# <img src='ml3.jpg'>
#
#
#
# <h2 style="color: blue"> Learning path to become Data Scientist in 3 Months</h2>
#
# <br>
#
# <li>The objective behind this session is to teach 3 Succesfull stpes to become data scientist</li>
#
# <li>All you need is 2-3 hrs of dedicated time for 3 months.</li>
#
# <li>In case of full time, the learning curve is much less</li>
#
#
# <img src='ml1.jpg', width=300, height=300>

# %% [markdown]
# # Month-1 : Learn  how to code
#
# <h3 style="color:red"> Start with Python (Hope fully) </h3>
#
# Be comfortable with basic concepts of Python
#
# Advanced Python optional
#
# ## Market Share of Programming Tools
#
# <img src='ml12.png' width=500>
#
# <b>Specifically Learn</b> : Lists, Tuples, Dictionaries, List comprehensions, Dictionary comprehensions, functions and controlflow
#
# <b> Learning Sources </b>: Python Blogs, YouTube, Udemy, Trainer
#
# <img src='ml5.png' width=800, height=700>

# %% [markdown]
# # Month-2 :
#
# ## Week 1 Pandas/Numpy/Scikit Learn(Python Libraries)
#
# #### 10 minitues to pandas
#
# https://pandas.pydata.org/pandas-docs/stable/10min.html
#
# #### Scikit-learn Machine Learning in python
#
# http://scikit-learn.org/stable/
#
# #### Numpy Quick Start Tutorial
# https://docs.scipy.org/doc/numpy-dev/user/quickstart.html
#
# <img src='ml7.png'>
#
#
# ## Week2 Data Exploration
#
# #### Descriptive statistics
#
# #### Central tendency
#
# #### Univariate Analysis
#
#
# ### Data Visualization
#
# #### Matplotlib
#
# https://matplotlib.org/tutorials/introductory/pyplot.html
#
# #### Seaborn
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial
#
# <img src='ml9.png' width=600, height=600>
#
#
#
# ## Week3 Data Preparation
#
#
# https://www.kdnuggets.com/2017/06/7-steps-mastering-data-preparation-python.html
#
# <img src='ml9.jpg' width=400, height=200>
#
# ## Week4 Basic Statistics
#
# https://www.coursera.org/learn/basic-statistics
#
# Correlation and Regression
#
# Probability
#
# Probability distributions
#
# Sampling distributions
#
# Hypothesis testing
#
# <img src='ml10.jpg'>

# %% [markdown]
# # Month-3 (Machine Learning)
#
# ## Week1 Supervised Machine Learning
#
# Regression(Linear, Logistic)
#
#
#
# ## Week2 Supervised Machine Learning
#
# Classification (KNN, Naive bayes, SVM-Linear)
#
# ## Week3 Supervised Machine Learning
#
# SVM-Non Linear, Decission Tree
#
#
# ## Week4 Un Supervised Machine Learning
#
# Clustering(K-Means)
#
# Basics Neural Network(AI)
#
# <img src='ml11.png'>

# %% [markdown]
# ## Work on projects
#
# To work on projects download the datasets from this opensource hubs. Upload it in GitHub, Kaggle or write a blog in Medium
#
# ### Data Sets
#
# #### Kaggle
#
# https://www.kaggle.com/
#
# #### quandl
#
# https://www.quandl.com/
#
# #### UCI
#
# https://archive.ics.uci.edu/ml/index.php

# %% [markdown]
# ## Kaggle Comptetion
#
# Kaggle is a platform for DataScience Competetion. This amplifies the power of your datascience talent.
#
# https://www.kaggle.com/competitions
#
# <br>
# <img src='kaggle.jpeg'>
